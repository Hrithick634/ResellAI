# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 8.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 892.3/892.3 kB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 2.6 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 28.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.4/802.4 kB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 29.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 31.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 31.7 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QgtOhplZcOFHNwWfu2IH")
project = rf.workspace("ww-fc7lq").project("my-first-project-kuvol")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-1 in yolov8:: 100%|██████████| 560/560 [00:00<00:00, 8300.12it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/hrithickkanagaraj/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

os.listdir(dataset.location)
# Out:
# ['README.roboflow.txt',
#  'valid',
#  'README.dataset.txt',
#  'test',
#  'data.yaml',
#  'train']

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/Users/hrithickkanagaraj/Documents/Programming /ML/Damage_classification/YOLOv8/data.yaml",
    epochs=70,
    imgsz=640,
    batch=8,
    patience=25,
    lr0=0.01,
    device="cpu"
)
# Out:
# Ultralytics 8.3.241 🚀 Python-3.13.5 torch-2.9.1 CPU (Apple M3)
# ...

# %%
metrics = model.val(
    data=f"{dataset.location}/data.yaml",
    conf=0.73,
    split="val"
)
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1560.1±351.1 MB/s, size: 57.4 KB)
# val: Scanning /content/My-First-Project-1/valid/labels.cache... 22 images, 8 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 22/22 32.2Kit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 25, len(boxes) = 33. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         22         33      0.812      0.394       0.62      0.538
# Speed: 8.7ms preprocess, 11.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/runs/detect/val4

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train2/weights/best.pt")

results = model.predict(
    source="/Users/hrithickkanagaraj/Documents/Programming /ML/Damage_classification/YOLOv8/Screenshot 2025-12-29 at 2.42.06 PM.png",
    conf=0.25,
    save=True
)
# Out:
# image 1/1 /Users/hrithickkanagaraj/Documents/Programming /ML/Damage_classification/YOLOv8/Screenshot 2025-12-29 at 2.42.06 PM.png: 416x640 (no detections), 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /Users/hrithickkanagaraj/Documents/Programming /ML/Damage_classification/YOLOv8/runs/detect/predict2
